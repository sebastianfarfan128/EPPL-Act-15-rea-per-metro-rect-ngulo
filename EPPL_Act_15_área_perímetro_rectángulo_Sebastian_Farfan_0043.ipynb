# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastianfarfan128/EPPL-Act-15-rea-per-metro-rect-ngulo/blob/main/EPPL_Act_15_%C3%A1rea_per%C3%ADmetro_rect%C3%A1ngulo_Sebastian_Farfan_0043.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Sebastian Farfan NL:16 Fecha 13/Abril/26
# ####📘 Redacción Congruente y Fórmulas Matemáticas
# ##### Este programa está diseñado para que estudiantes de preparatoria comprendan los fundamentos de la programación estructurada en Python resolviendo problemas geométricos cotidianos. El código sigue un enfoque modular y procedural, lo que significa que cada tarea se delega a funciones independientes, facilitando la lectura, mantenimiento y comprensión del flujo de ejecución sin necesidad de utilizar clases ni objetos.
# * Para los cálculos geométricos se aplican las siguientes fórmulas matemáticas básicas:
# 1. Área del rectángulo:
# $A=b×h$
# 2. Perímetro del rectángulo:
# $P=2⋅(b+h)$
# * Donde b representa la medida de la base y h la medida de la altura de la figura.

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/sebastianfarfan128/EPPL-Act-15-rea-per-metro-rect-ngulo/refs/heads/main/calculo%20del%20area%20de%20un%20rectangulo%20formulas%20y%20ejemplos.png)
# * El comportamiento del programa se controla mediante la función $menu()$, la cual despliega las opciones disponibles al usuario.
# * Un ciclo while mantiene el programa en ejecución de forma continua hasta que se seleccione la opción de salida.
# * Dentro del ciclo, las estructuras condicionales if, elif y else interpretan la elección del usuario y dirigen la ejecución hacia la función correspondiente.
# * Tanto $arearectangulo()$ como $perimetrorectangulo()$ solicitan los valores de base y altura en el momento de ser llamadas, realizan el cálculo matemático y muestran el resultado en pantalla con un formato limpio.
# * No se incluye validación de entrada de datos para mantener el código enfocado exclusivamente en la lógica de control y llamadas a funciones. La interfaz utiliza emojis para hacer la interacción más visual y amigable.

# %%
def arearectangulo():
    """Calcula y muestra el área de un rectángulo."""
    print("\n📐 Cálculo del Área del Rectángulo")
    base = float(input("📥 Ingresa la base del rectángulo: "))
    altura = float(input("📥 Ingresa la altura del rectángulo: "))
    area = base * altura
    print(f"✅ El área del rectángulo es: {area:.2f} unidades²")

def perimetrorectangulo():
    """Calcula y muestra el perímetro de un rectángulo."""
    print("\n📏 Cálculo del Perímetro del Rectángulo")
    base = float(input("📥 Ingresa la base del rectángulo: "))
    altura = float(input("📥 Ingresa la altura del rectángulo: "))
    perimetro = 2 * (base + altura)
    print(f"✅ El perímetro del rectángulo es: {perimetro:.2f} unidades")

def menu():
    """Muestra el menú interactivo y controla el flujo del programa."""
    opcion = 0
    while opcion != 3:
        print("\n🔹 ══════ MENÚ PRINCIPAL ══════ 🔹")
        print("1️⃣  Calcular área del rectángulo")
        print("2️⃣  Calcular perímetro del rectángulo")
        print("3️⃣  Salir del programa")
        print("═══════════════════════════════")

        opcion = int(input("👉 Elige una opción (1-3): "))

        if opcion == 1:
            arearectangulo()
        elif opcion == 2:
            perimetrorectangulo()
        elif opcion == 3:
            print("\n👋 ¡Gracias por usar el programa! Hasta pronto. ✨")
        else:
            print("⚠️ Opción no válida. Por favor, selecciona un número del 1 al 3.")

# Punto de entrada del programa
if __name__ == "__main__":
    menu()
# Out:
# 🔹 ══════ MENÚ PRINCIPAL ══════ 🔹
# 1️⃣  Calcular área del rectángulo
# 2️⃣  Calcular perímetro del rectángulo
# 3️⃣  Salir del programa
# ═══════════════════════════════
# 👉 Elige una opción (1-3): 1
#
# 📐 Cálculo del Área del Rectángulo
# 📥 Ingresa la base del rectángulo: 12
# 📥 Ingresa la altura del rectángulo: 23
# ✅ El área del rectángulo es: 276.00 unidades²
#
# 🔹 ══════ MENÚ PRINCIPAL ══════ 🔹
# 1️⃣  Calcular área del rectángulo
# 2️⃣  Calcular perímetro del rectángulo
# 3️⃣  Salir del programa
# ═══════════════════════════════
# 👉 Elige una opción (1-3): 2
#
# 📏 Cálculo del Perímetro del Rectángulo
# 📥 Ingresa la base del rectángulo: 69
# 📥 Ingresa la altura del rectángulo: 4
# ✅ El perímetro del rectángulo es: 146.00 unidades
#
# 🔹 ══════ MENÚ PRINCIPAL ══════ 🔹
# 1️⃣  Calcular área del rectángulo
# 2️⃣  Calcular perímetro del rectángulo
# 3️⃣  Salir del programa
# ═══════════════════════════════
# 👉 Elige una opción (1-3): 3
#
# ...

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/sebastianfarfan128/EPPL-Act-15-rea-per-metro-rect-ngulo/refs/heads/main/Tldraw%20area%20y%20perimetro%20de%20un%20rectangulo.jpeg)
